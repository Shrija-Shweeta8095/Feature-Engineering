# %% [markdown]
# ## Feature Scaling
# ### Standardization and Normalization

# %%
import pandas as pd
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
df=sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df2=df[['survived','pclass','age','parch']]

# %%
df2
# Out:
#      survived  pclass   age  parch
# 0           0       3  22.0      0
# 1           1       1  38.0      0
# 2           1       3  26.0      0
# 3           1       1  35.0      0
# 4           0       3  35.0      0
# ..        ...     ...   ...    ...
# 886         0       2  27.0      0
# 887         1       1  19.0      0
# 888         0       3   NaN      2
# 889         1       1  26.0      0
# 890         0       3  32.0      0
#
# [891 rows x 4 columns]

# %%
df2.head()
# Out:
#    survived  pclass   age  parch
# 0         0       3  22.0      0
# 1         1       1  38.0      0
# 2         1       3  26.0      0
# 3         1       1  35.0      0
# 4         0       3  35.0      0

# %%
df3=df2.fillna(df2.mean())

# %%
X=df3.drop('survived',axis=1)
Y=df3['survived']
print("Shape of X:",X.shape)
print("Shape of Y:",Y.shape)
# Out:
# Shape of X: (891, 3)
# Shape of Y: (891,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=51)

# %%
print("Shape of X_train:",X_train.shape)
print("Shape of Y_train:",Y_train.shape)
print("Shape of X_test:",X_test.shape)
print("Shape of Y_test:",Y_test.shape)
# Out:
# Shape of X_train: (712, 3)
# Shape of Y_train: (712,)
# Shape of X_test: (179, 3)
# Shape of Y_test: (179,)

# %%
sc=StandardScaler()
sc.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
sc.mean_
# Out:
# array([ 2.30617978, 29.55409121,  0.39185393])

# %%
sc.scale_  #Standard Deviation
# Out:
# array([ 0.84405789, 12.99162985,  0.79647463])

# %%
X_train.describe()
# Out:
#            pclass         age       parch
# count  712.000000  712.000000  712.000000
# mean     2.306180   29.554091    0.391854
# std      0.844651   13.000763    0.797035
# min      1.000000    0.420000    0.000000
# 25%      1.750000   22.000000    0.000000
# 50%      3.000000   29.699118    0.000000
# 75%      3.000000   35.000000    0.000000
# max      3.000000   71.000000    5.000000

# %%
X_train_sc=sc.transform(X_train)
X_test_sc=sc.transform(X_test)

# %%
X_train_sc
# Out:
# array([[-1.75837972, -2.30776312, -1.1096893 ],
#        [-1.75837972, -2.12113234, -1.1096893 ],
#        [-1.75837972, -2.38478535, -1.1096893 ],
#        ...,
#        [-1.75837972, -2.16556824,  3.61939826],
#        [-1.75837972, -2.27399706,  0.46667322],
#        [-1.75837972, -2.28110158, -1.1096893 ]])

# %%
X_test_sc
# Out:
# array([[-4.56565841, -2.21296653, -1.1096893 ],
#        [-1.75837972, -2.26036483, -1.1096893 ],
#        [-1.75837972, -2.2722144 , -1.1096893 ],
#        [-4.56565841, -2.27399706, -1.1096893 ],
#        [-3.16201907, -2.24851525,  0.46667322],
#        [-1.75837972, -2.26036483, -1.1096893 ],
#        [-4.56565841, -2.17149303, -1.1096893 ],
#        [-1.75837972, -2.35516142, -1.1096893 ],
#        [-3.16201907, -2.05892208, -1.1096893 ],
#        [-4.56565841, -2.3610862 ,  0.46667322],
#        [-3.16201907, -2.26628961, -1.1096893 ],
#        [-3.16201907, -2.28406397, -1.1096893 ],
#        [-4.56565841, -2.1833426 , -1.1096893 ],
#        [-1.75837972, -2.31368791, -1.1096893 ],
#        [-1.75837972, -2.20704175,  6.77212331],
#        [-3.16201907, -2.30183833, -1.1096893 ],
#        [-3.16201907, -2.23666568,  2.04303574],
#        [-1.75837972, -2.27399706, -1.1096893 ],
#        [-1.75837972, -2.27399706, -1.1096893 ],
#        [-3.16201907, -2.33738705, -1.1096893 ],
# ...

# %%
x_train_sc1=pd.DataFrame(X_train_sc,columns=["pclass","age","parch"])
x_test_sc1=pd.DataFrame(X_test_sc,columns=["pclass","age","parch"])

# %%
x_train_sc1.head()
# Out:
#     pclass       age     parch
# 0 -1.75838 -2.307763 -1.109689
# 1 -1.75838 -2.121132 -1.109689
# 2 -1.75838 -2.384785 -1.109689
# 3 -1.75838 -2.343312 -1.109689
# 4 -1.75838 -2.273997  2.043036

# %%
x_test_sc1.head()
# Out:
#      pclass       age     parch
# 0 -4.565658 -2.212967 -1.109689
# 1 -1.758380 -2.260365 -1.109689
# 2 -1.758380 -2.272214 -1.109689
# 3 -4.565658 -2.273997 -1.109689
# 4 -3.162019 -2.248515  0.466673

# %%
x_train_sc1.describe().round(2)
# Out:
#        pclass     age   parch
# count  712.00  712.00  712.00
# mean    -2.73   -2.27   -0.49
# std      1.19    0.08    1.26
# min     -4.57   -2.45   -1.11
# 25%     -3.51   -2.32   -1.11
# 50%     -1.76   -2.27   -1.11
# 75%     -1.76   -2.24   -1.11
# max     -1.76   -2.03    6.77

# %%
mmc=MinMaxScaler()

# %%
mmc.fit(X_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train_mmc=mmc.transform(X_train)
X_test_mmc=mmc.transform(X_test)

# %%
X_train_mmc
# Out:
# array([[1.        , 0.33408898, 0.        ],
#        [1.        , 0.78039105, 0.        ],
#        [1.        , 0.14990082, 0.        ],
#        ...,
#        [1.        , 0.67412865, 0.6       ],
#        [1.        , 0.4148359 , 0.2       ],
#        [1.        , 0.39784642, 0.        ]])

# %%
x_train_mmc1=pd.DataFrame(X_train_mmc,columns=["pclass","age","parch"])
x_test_mmc1=pd.DataFrame(X_test_mmc,columns=["pclass","age","parch"])

# %%
x_train_mmc1.describe().round(2)
# Out:
#        pclass     age   parch
# count  712.00  712.00  712.00
# mean     0.65    0.41    0.08
# std      0.42    0.18    0.16
# min      0.00    0.00    0.00
# 25%      0.38    0.31    0.00
# 50%      1.00    0.41    0.00
# 75%      1.00    0.49    0.00
# max      1.00    1.00    1.00

# %%
sns.pairplot(X_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-ba1743b46935> in <module>
# ----> 1 sns.pairplot(X_train)
#
# E:\ml_and_dl\env\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2072
#    2073     if not isinstance(data, pd.DataFrame):
# -> 2074         raise TypeError(
#    2075             "'data' must be pandas DataFrame object, not: {typefound}".format(
#    2076                 typefound=type(data)))
#
# TypeError: 'data' must be pandas DataFrame object, not: <class 'numpy.ndarray'>

# %%
sns.pairplot(X_train_sc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-d80d47e65222> in <module>
# ----> 1 sns.pairplot(X_train_sc)
#
# E:\ml_and_dl\env\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2072
#    2073     if not isinstance(data, pd.DataFrame):
# -> 2074         raise TypeError(
#    2075             "'data' must be pandas DataFrame object, not: {typefound}".format(
#    2076                 typefound=type(data)))
#
# TypeError: 'data' must be pandas DataFrame object, not: <class 'numpy.ndarray'>

# %%
sns.pairplot(X_train_mmc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-8876621523b9> in <module>
# ----> 1 sns.pairplot(X_train_mmc)
#
# E:\ml_and_dl\env\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2072
#    2073     if not isinstance(data, pd.DataFrame):
# -> 2074         raise TypeError(
#    2075             "'data' must be pandas DataFrame object, not: {typefound}".format(
#    2076                 typefound=type(data)))
#
# TypeError: 'data' must be pandas DataFrame object, not: <class 'numpy.ndarray'>
